# %% [markdown]
# # Archivos

# %% [markdown]
# Desde google drive con el ID que proporciona al dar clic derecho en el archivo y obtener el enlace para compartir.
#
# https://drive.google.com/open?id=1YfMCQiTwc-TYeqn_57oIuqMECRuQvy63

# %%
# !pip install PyDrive
import os
from shutil import copy
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Out:
# ...
#      |████████████████████████████████| 993kB 3.4MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/fa/d2/9a/d3b6b506c2da98289e5d417215ce34b696db856643bad779f4
# Successfully built PyDrive
# ...

# %%
fileIdLabelmap = '1zVAl1QuWFXYqjgMh50cm0EPgQoE4I3e4'
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

downloaded1 = drive.CreateFile({'id': fileIdLabelmap})
downloaded1.GetContentFile("doc.txt")

# %%
# !ls
# Out:
# adc.json  doc.txt

# %%
file=open("doc.txt", "r")
contents =file.read()
print(contents)
# Out:
# documento de prueba para colab

# %% [markdown]
# ## Desde la computadora
#
# Con las siguientes líneas pueden cargar y descargar los archivos del entorno de colabab a la computadora y viceversa

# %%
from google.colab import files

#Subir archivo
uploaded = files.upload()
# Out:
#      <input type="file" id="files-82afb0e5-68e6-44ef-8c57-4f9fd1a1aa38" name="files[]" multiple disabled />
#      <output id="result-82afb0e5-68e6-44ef-8c57-4f9fd1a1aa38">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving carta.odt to carta.odt

# %%
# !ls
# Out:
# adc.json  carta.odt  doc.txt

# %%
#Descargar archivo

files.download('doc.txt')

# %% [markdown]
#  Descarga desde github

# %%
! git clone https://github.com/Duchanoy/DNN_magnet.git
# Out:
# Cloning into 'DNN_magnet'...
# remote: Enumerating objects: 157, done.
# remote: Total 157 (delta 0), reused 0 (delta 0), pack-reused 157
# Receiving objects: 100% (157/157), 7.64 MiB | 29.86 MiB/s, done.
# Resolving deltas: 100% (59/59), done.

# %%
# !ls
# Out:
# 'AR IMP IMAGES'    'Minuta Sprint 1 AR-IMP.gdoc'		     SS.gsheet
#  Classroom	   'Plan de alimentaciòn 1 Rodrigo Burciaga .docx'
# 'Colab Notebooks'   pruebacolab.txt

# %% [markdown]
# Montar drive

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !ls "/content/drive/My Drive/"
# Out:
# 'AR IMP IMAGES'    'Minuta Sprint 1 AR-IMP.gdoc'		     SS.gsheet
#  Classroom	   'Plan de alimentaciòn 1 Rodrigo Burciaga .docx'
# 'Colab Notebooks'   pruebacolab.txt

# %% [markdown]
# #Uso de comandos Shell
#
# Colaboratory permite el uso de comandos Shell de linux  para navegar entre los directorios y archivos que se encuentran anexos al ambiente

# %% [markdown]
# !ls
# : Lista el contenido de un directorio. Si lo usamos sin argumentos, lista el contenido del directorio actual o corriente. Por más información
#
# %cd
#
# Cambia el directorio corriente (Change Directory) en que nos encontramos posicionados. Si se utiliza sin argumentos, cambia al directorio raíz del homedir del usuario
#
# !pwd
#
# Imprime el directorio de trabajo actual
#
# !rm < file >
#
# Elimina archivos o directorios.

# %% [markdown]
# Los comnados shell se puede usar dentro de python
#
# In [4]: contents = !ls
#
# In [5]: print(contents)
# ['myproject.txt']
#
# In [6]: directory = !pwd
#
# In [7]: print(directory)

# %% [markdown]
# # Ejecutar un archivo python

# %%
# !python <namefile>

# %% [markdown]
# #Instalar una biblioteca que no esta en Colaboratory
#
#  Para importar una biblioteca que no está en Colaboratory por defecto, puede usar** !pip install** or **!apt-get install.**

# %%
# !pip install -q matplotlib-venn
